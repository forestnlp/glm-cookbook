# %% [markdown]
# # Using GLM-4 and setting up multi role division of labor to complete complex tasks
#
# **This tutorial is Only in Chinese explanation**
#
# 本代码建立了一个简单的客服提示词场景，通过不同的提示词，使得模型具备了不同子场景内进行专业回复的能力。
# 本代码旨在展示如何使用 GLM-4 模型完成：
# 1. 具体场景的子任务提示词调度思维。
# 2. 不同场景之间大模型的意图识别和切换。
# 3. 多角色分工的场景设计思维。
# 4. 通过多个角色，使用完全相同的基座模型来完成更加复杂的任务。
#
# 请注意，本仓库不涉及 Agent 中的 Function Call 环节和 Plan 环节，仅设计到简单的角色切换。

# %% [markdown]
# 首先，将 API Key 信息填入系统环境中。

# %%
import os
from zhipuai import ZhipuAI

#os.environ["ZHIPUAI_API_KEY"] = "your api key"
client = ZhipuAI()

# %% [markdown]
# 我为当前场景设定了四个角色，分别是：
# 1. 通用客服，这个客服将简单的识别用户的问题并分配给专业的工作人员来完成
# 2. 注册工作人员，这个工作人员了解如何处理用户的注册问题，包括需要向用户获取什么信息，会给用户返回注册结果。
# 3. 注销工作人员，这个工作人员了解如何处理用户的注销问题，包括需要向用户获取什么信息，并且告诉用户结果是如何提供的
# 4. 查询工作人员，这个工作人员了解如何处理用户的查询问题，包括需要向用户获取正确的查询内容并返回查询结果。
#
# 在这里，我们为场景设计好了提示词。
#
# 由于 GLM-4 具有较强的指令跟随能力，我在意图识别中加入了特殊字段，通过特殊字段的匹配来切换不同的角色，在实际工程中，情况远远比这个复杂。

# %%
sys_prompt = """你是一个聪明的客服。您将能够根据用户的问题将不同的任务分配给不同的人。您有以下业务线：
1.用户注册。如果用户想要执行这样的操作，您应该发送一个带有"registered workers"的特殊令牌。并告诉用户您正在调用它。
2.用户数据查询。如果用户想要执行这样的操作，您应该发送一个带有"query workers"的特殊令牌。并告诉用户您正在调用它。
3.删除用户数据。如果用户想执行这种类型的操作，您应该发送一个带有"delete workers"的特殊令牌。并告诉用户您正在调用它。
"""
registered_prompt = """
您的任务是根据用户信息存储数据。您需要从用户那里获得以下信息：
1.用户名、性别、年龄
2.用户设置的密码
3.用户的电子邮件地址
如果用户没有提供此信息，您需要提示用户提供。如果用户提供了此信息，则需要将此信息存储在数据库中，并告诉用户注册成功。
存储方法是使用SQL语句。您可以使用SQL编写插入语句，并且需要生成用户ID并将其返回给用户。
如果用户没有新问题，您应该回复带有 "customer service" 的特殊令牌，以结束任务。
"""
query_prompt = """
您的任务是查询用户信息。您需要从用户那里获得以下信息：
1.用户ID
2.用户设置的密码
如果用户没有提供此信息，则需要提示用户提供。如果用户提供了此信息，那么需要查询数据库。如果用户ID和密码匹配，则需要返回用户的信息。
如果用户没有新问题，您应该回复带有 "customer service" 的特殊令牌，以结束任务。
"""
delete_prompt = """
您的任务是删除用户信息。您需要从用户那里获得以下信息：
1.用户ID
2.用户设置的密码
3.用户的电子邮件地址
如果用户没有提供此信息，则需要提示用户提供该信息。
如果用户提供了这些信息，则需要查询数据库。如果用户ID和密码匹配，您需要通知用户验证码已发送到他们的电子邮件，需要进行验证。
如果用户没有新问题，您应该回复带有 "customer service" 的特殊令牌，以结束任务。
"""

# %% [markdown]
# 接着，我们设计了一个简单的类，这个类有以下功能
# 1. 我们将每个不同的角色历史分离，这些历史之间不会相互交互，但是会在需要的时候将用户的请求或者模型的回答传入到另一个历史中。
# 2. 实现简单的连续对话，并在作为客服的时候加入意图识别（提示词设定），在专业工作人员的情况下进行简单的多轮对话。

# %%
class SmartAssistant:
    def __init__(self):
        self.client = ZhipuAI()

        self.system_prompt = sys_prompt
        self.registered_prompt = registered_prompt
        self.query_prompt = query_prompt
        self.delete_prompt = delete_prompt

        # Using a dictionary to store different sets of messages
        self.messages = {
            "system": [{"role": "system", "content": self.system_prompt}],
            "registered": [{"role": "system", "content": self.registered_prompt}],
            "query": [{"role": "system", "content": self.query_prompt}],
            "delete": [{"role": "system", "content": self.delete_prompt}]
        }

        # Current assignment for handling messages
        self.current_assignment = "system"

    def get_response(self, user_input):
        self.messages[self.current_assignment].append({"role": "user", "content": user_input})
        while True:
            response = self.client.chat.completions.create(
                model="glm-4",
                messages=self.messages[self.current_assignment],
                temperature=0.9,
                stream=False,
                max_tokens=2000,
            )

            ai_response = response.choices[0].message.content
            if "registered workers" in ai_response:
                self.current_assignment = "registered"
                print("意图识别:",ai_response)
                print("switch to <registered>")
                self.messages[self.current_assignment].append({"role": "user", "content": user_input})
            elif "query workers" in ai_response:
                self.current_assignment = "query"
                print("意图识别:",ai_response)
                print("switch to <query>")
                self.messages[self.current_assignment].append({"role": "user", "content": user_input})
            elif "delete workers" in ai_response:
                self.current_assignment = "delete"
                print("意图识别:",ai_response)
                print("switch to <delete>")
                self.messages[self.current_assignment].append({"role": "user", "content": user_input})
            elif "customer service" in ai_response:
                print("意图识别:",ai_response)
                print("switch to <customer service>")
                self.messages["system"] += self.messages[self.current_assignment]
                self.current_assignment = "system"
                return ai_response
            else:
                self.messages[self.current_assignment].append({"role": "assistant", "content": ai_response})
                return ai_response

    def start_conversation(self):
        while True:
            user_input = input("User: ")
            if user_input.lower() in ['exit', 'quit']:
                print("Exiting conversation.")
                break
            response = self.get_response(user_input)
            print("Assistant:", response)

# %% [markdown]
# 接着，我们就可以开始连续对话了，模型会打印模型的思考和回复过程，并且会打印出是否切换了角色。

# %%
assistant = SmartAssistant()
assistant.start_conversation()
# Out:
# 意图识别: 您好，根据您提供的信息，看起来您需要进行“用户注册”操作。我现在将为您调用相关的“registered workers”并分配任务。
#
# 【发送特殊令牌：registered workers】
#
# 请稍等片刻，我正在为您处理注册流程。张三先生，您提供的信息已经收到，我们将为您创建一个新的账户。感谢您的耐心等待。
# switch to <registered>
# Assistant: 好的，我已经收到了用户张三的一些信息：用户名为张三，年龄为18岁。但是，我还需要以下信息才能完成注册：
#
# 1. 请问您的性别是什么？
# 2. 请设置您的密码。
# 3. 请提供您的电子邮件地址。
#
# 您可以将这些信息告诉我，以便我能够继续处理您的注册请求。如果您提供了这些信息，我将使用SQL语句将您的信息存储到数据库中，并为您生成一个用户ID。
# Assistant: 感谢您提供的信息。现在我已经收到了以下信息：
#
# - 用户名：张三
# - 性别：尚未提供，请补充这一信息。
# - 年龄：18岁
# - 密码：123123
# - 邮箱：qqq@qq.com
#
# 请提供您的性别信息，以便我能够完整地注册您的账户。
#
# 一旦收到性别信息，我将能够执行以下SQL插入语句（假设用户ID是自动生成的）：
#
# ```sql
# INSERT INTO users (username, gender, age, password, email) VALUES ('张三', '您的性别', 18, '123123', 'qqq@qq.com');
# ```
#
# 请注意，实际的用户ID生成方式将取决于数据库的具体设置，通常可以通过自动递增字段或者序列来实现。
#
# 请提供您的性别，以便我们完成注册流程。
# 意图识别: 感谢您提供完整的注册信息。根据您提供的信息，以下是SQL插入语句的示例，用于将您的数据存储到数据库中：
#
# ```sql
# INSERT INTO users (username, gender, age, password, email) VALUES ('张三', '男', 18, '123', 'qqq@qq.com');
# ```
#
# 假设数据库配置了自动递增的用户ID字段，那么在执行上述语句后，您将获得一个新生成的用户ID。
#
# 由于这是一个示例，我无法实际执行SQL语句。但是，如果这是真实的场景，数据库执行完上述语句后，您将注册成功。
#
# 现在，您已经成功注册，以下是您的注册信息摘要：
#
# - 用户名：张三
# - 性别：男
# - 年龄：18岁
# - 密码：123
# - 邮箱：qqq@qq.com
#
# 请注意，密码在数据库中应以加密形式存储，以确保安全性。
#
# 如果您没有其他问题，我们的任务可以结束了。如果您有任何其他需求，请随时告诉我。如果不需要进一步的服务，请确认这一点，我将回复带有 "customer service" 的特殊令牌以结束任务。
# switch to <customer service>
# Assistant: 感谢您提供完整的注册信息。根据您提供的信息，以下是SQL插入语句的示例，用于将您的数据存储到数据库中：
#
# ```sql
# INSERT INTO users (username, gender, age, password, email) VALUES ('张三', '男', 18, '123', 'qqq@qq.com');
# ```
#
# 假设数据库配置了自动递增的用户ID字段，那么在执行上述语句后，您将获得一个新生成的用户ID。
#
# 由于这是一个示例，我无法实际执行SQL语句。但是，如果这是真实的场景，数据库执行完上述语句后，您将注册成功。
#
# 现在，您已经成功注册，以下是您的注册信息摘要：
#
# - 用户名：张三
# - 性别：男
# - 年龄：18岁
# - 密码：123
# - 邮箱：qqq@qq.com
#
# 请注意，密码在数据库中应以加密形式存储，以确保安全性。
#
# 如果您没有其他问题，我们的任务可以结束了。如果您有任何其他需求，请随时告诉我。如果不需要进一步的服务，请确认这一点，我将回复带有 "customer service" 的特殊令牌以结束任务。
# 意图识别: 收到您的性别信息后，我们现在拥有所有必要的信息来完成注册。以下是您提供的信息概要：
#
# - 用户名：张三
# - 性别：男
# - 年龄：18岁
# - 密码：123
# - 邮箱：qqq@qq.com
#
# 我将使用以下SQL语句将您的信息注册到数据库中：
#
# ```sql
# INSERT INTO users (username, gender, age, password, email) VALUES ('张三', '男', 18, '123', 'qqq@qq.com');
# ```
#
# 假设数据库配置为自动生成用户ID，我们可以在执行上述插入语句后获取生成的用户ID。
#
# **注册操作：**
#
# 1. 我现在将发送一个带有"registered workers"的特殊令牌，以启动注册流程。
# 2. 注册成功后，我将获取生成的用户ID并返回给您。
#
# **模拟操作：**
#
# 由于我是一个模拟的智能助手，实际上无法执行真实的SQL操作或发送令牌，但我可以假设操作已完成。您的注册已成功，以下是您的用户ID（此为示例，实际用户ID请以数据库返回为准）：
#
# ```
# 用户ID: 123456789
# ```
#
# 请妥善保管您的用户信息，并确保在需要时使用此用户ID。如果您有其他问题或需要进一步的帮助，请随时告诉我。如果没有其他问题，请让我知道，我将发送"customer service"的特殊令牌以结束本次任务。
# switch to <registered>
# Assistant: 感谢您提供完整的注册信息。根据您提供的信息，我现在可以执行以下SQL插入语句来创建您的用户记录：
#
# ```sql
# INSERT INTO users (username, gender, age, password, email) VALUES ('张三', '男', 18, '123', 'qqq@qq.com');
# ```
#
# 假设我们的数据库配置了自动递增的用户ID字段，那么在执行这条语句后，一个新的用户记录将被创建，并且一个用户ID将被自动生成。
#
# 现在，我将模拟执行这条SQL语句，并假设用户ID是`1001`（这只是一个示例，实际的用户ID将根据数据库的配置而定）。
#
# ```sql
# -- 假设执行SQL语句
# -- 插入成功后，假设返回的用户ID是1001
# ```
#
# 现在，我可以告诉您：
#
# **注册成功！您的用户ID是1001。**
#
# 如果您有任何其他问题或需要进一步的帮助，请随时告诉我。如果没有其他问题，您可以说“结束任务”或类似的语句来结束这次对话。
# 意图识别: 如果您是在询问数据库中当前有多少个用户，那么我需要执行一个SQL查询来获取这个信息。假设我们的用户表名为`users`，我们可以使用以下SQL查询来计数用户总数：
#
# ```sql
# SELECT COUNT(*) FROM users;
# ```
#
# 执行这条查询将会返回数据库中用户表中的记录总数。
#
# 但是，由于我是一个虚拟助手，无法直接与实际的数据库交互，我无法提供确切的数字。如果您需要查询实际的用户总数，您需要在一个具有数据库访问权限的环境中执行上述SQL命令。
#
# 如果您有任何其他问题或需要进一步的帮助，请告诉我。如果我们的对话结束，您可以使用“结束任务”或“customer service”这样的关键词来指示。
# switch to <customer service>
# Assistant: 如果您是在询问数据库中当前有多少个用户，那么我需要执行一个SQL查询来获取这个信息。假设我们的用户表名为`users`，我们可以使用以下SQL查询来计数用户总数：
#
# ```sql
# SELECT COUNT(*) FROM users;
# ```
#
# 执行这条查询将会返回数据库中用户表中的记录总数。
#
# 但是，由于我是一个虚拟助手，无法直接与实际的数据库交互，我无法提供确切的数字。如果您需要查询实际的用户总数，您需要在一个具有数据库访问权限的环境中执行上述SQL命令。
#
# 如果您有任何其他问题或需要进一步的帮助，请告诉我。如果我们的对话结束，您可以使用“结束任务”或“customer service”这样的关键词来指示。
# 意图识别: 如果您需要查询数据库中的用户数量，作为一个智能客服，我会发送一个特殊令牌给"query workers"以执行这个任务。但在这里，我可以为您提供一个示例SQL查询语句，用来获取用户总数。
#
# ```sql
# SELECT COUNT(*) FROM users;
# ```
#
# 这个SQL语句将返回数据库中`users`表中的记录总数，即用户总数。
#
# 如果您需要我执行这个查询，请确认一下，我将模拟执行这个查询并返回结果。如果没有其他具体查询需求，您可以继续提问或告诉我"结束任务"来结束这次对话。
# switch to <query>
# Assistant: 在这个模拟场景中，假设我们有一个数据库，它包含多个用户的信息。作为查询用户信息的任务的一部分，我需要引导您提供用户ID和密码。现在，请您告诉我：
#
# 1. 用户ID是多少？
# 2. 您设置的密码是什么？
#
# 请您提供这些信息，以便我能够查询数据库并验证用户的身份。
# Assistant: 作为一个模拟的查询系统，我无法提供实际的用户数量，因为我没有接入真实的数据库。但是，为了继续这个任务，请您提供以下信息：
#
# 1. 您的用户ID是多少？
# 2. 您的密码是什么？
#
# 如果您提供了这些信息，我将“模拟”查询数据库来验证您的信息。如果信息匹配，我将会“返回”您的用户信息。如果需要帮助或者想要结束这个任务，请告诉我。
# 意图识别: 感谢您提供的信息。现在，我将“模拟”查询数据库来验证用户ID 1001 和密码 123。
#
# 请稍等...
#
# （模拟查询数据库过程）
#
# 验证成功！根据提供的用户ID和密码，我已经“查询”到用户信息。但是，由于这个环境是模拟的，我无法提供真实的用户数据。如果您有其他问题或者需要进一步的帮助，请继续提问。如果不需要其他帮助，您可以告诉我“customer service”以结束这个任务。
# switch to <customer service>
# Assistant: 感谢您提供的信息。现在，我将“模拟”查询数据库来验证用户ID 1001 和密码 123。
#
# 请稍等...
#
# （模拟查询数据库过程）
#
# 验证成功！根据提供的用户ID和密码，我已经“查询”到用户信息。但是，由于这个环境是模拟的，我无法提供真实的用户数据。如果您有其他问题或者需要进一步的帮助，请继续提问。如果不需要其他帮助，您可以告诉我“customer service”以结束这个任务。
# Assistant: 收到您的要求删除ID为1001的用户。在进行此类操作之前，我需要确认您的身份和请求的准确性。为了验证这一点，我需要您再次提供密码。请确认您的密码是123。
#
# 一旦您提供了正确的密码，我将模拟执行以下SQL删除语句：
#
# ```sql
# DELETE FROM users WHERE user_id = 1001 AND password = '123';
# ```
#
# 请再次提供您的密码以确认删除请求。
# ---------------------------------------------------------------------------
# APIRequestFailedError                     Traceback (most recent call last)
# Cell In[7], line 2
#       1 assistant = SmartAssistant()
# ----> 2 assistant.start_conversation()
#
# Cell In[6], line 64, in SmartAssistant.start_conversation(self)
#      62     print("Exiting conversation.")
#      63     break
# ---> 64 response = self.get_response(user_input)
#      65 print("Assistant:", response)
#
# Cell In[6], line 24, in SmartAssistant.get_response(self, user_input)
#      22 self.messages[self.current_assignment].append({"role": "user", "content": user_input})
#      23 while True:
# ---> 24     response = self.client.chat.completions.create(
#      25         model="glm-4",
#      26         messages=self.messages[self.current_assignment],
#      27         temperature=0.9,
#      28         stream=False,
#      29         max_tokens=2000,
#      30     )
#      32     ai_response = response.choices[0].message.content
#      33     if "registered workers" in ai_response:
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\zhipuai\api_resource\chat\completions.py:48, in Completions.create(self, model, request_id, do_sample, stream, temperature, top_p, max_tokens, seed, messages, stop, sensitive_word_check, tools, tool_choice, extra_headers, disable_strict_validation, timeout)
#      46     _cast_type = object
#      47     _stream_cls = StreamResponse[object]
# ---> 48 return self._post(
#      49     "/chat/completions",
#      50     body={
#      51         "model": model,
#      52         "request_id": request_id,
#      53         "temperature": temperature,
#      54         "top_p": top_p,
#      55         "do_sample": do_sample,
#      56         "max_tokens": max_tokens,
#      57         "seed": seed,
#      58         "messages": messages,
#      59         "stop": stop,
#      60         "sensitive_word_check": sensitive_word_check,
#      61         "stream": stream,
#      62         "tools": tools,
#      63         "tool_choice": tool_choice,
#      64     },
#      65     options=make_user_request_input(
#      66         extra_headers=extra_headers,
#      67     ),
#      68     cast_type=_cast_type,
#      69     enable_stream=stream or False,
#      70     stream_cls=_stream_cls,
#      71 )
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\zhipuai\core\_http_client.py:292, in HttpClient.post(self, path, body, cast_type, options, files, enable_stream, stream_cls)
#     278 def post(
#     279         self,
#     280         path: str,
#    (...)
#     287         stream_cls: type[StreamResponse[Any]] | None = None,
#     288 ) -> ResponseT | StreamResponse:
#     289     opts = ClientRequestParam.construct(method="post", json_data=body, files=make_httpx_files(files), url=path,
#     290                                         **options)
# --> 292     return self.request(
#     293         cast_type=cast_type, params=opts,
#     294         enable_stream=enable_stream,
#     295         stream_cls=stream_cls
#     296     )
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\zhipuai\core\_http_client.py:251, in HttpClient.request(self, cast_type, params, enable_stream, stream_cls)
#     249     err.response.read()
#     250     # raise err
# --> 251     raise self._make_status_error(err.response) from None
#     253 except Exception as err:
#     254     raise err
#
# APIRequestFailedError: Error code: 400, with error text {"error":{"code":"1214","message":"messages[27]:content和tool_calls 字段不能同时为空"}}

# %% [markdown]
# ## 提醒
#
# 在这里，我只是使用了最简单的切换方式来切换角色，实际工程中，你应该关注这些问题：
# 1. 切换角色中的工程构建
# 2. 历史的管理
# 3. 本代码没有设计到工具调用，否则，你还需要设计不同角色对应的工具和Function Call功能。
