# %% [markdown]
# # Using ZhipuAI GLM-4 in Langchain
#
# **This tutorial is available in English and is attached below the Chinese explanation**
#
# 本代码，我们将带领大家如何使用 Langchain 来调用 ZhipuAI 的 GLM-4 模型。
# 你将在本章节学习到如何使用 Langchain 的 `ChatZhipuAI` 类来调用 ZhipuAI 的 GLM-4 模型，以及如何使用 `ChatZhipuAI` 类来实现类似 `ChatOpenAI` 的方法来进行调用。
#
# In this notebook, I will show you how to use Langchain to call ZhipuAI's GLM-4 model.
# In this chapter, you will learn how to use Langchain's `ChatZhipuAI` class to call ZhipuAI's GLM-4 model, and how to use the `ChatZhipuAI` class to implement methods similar to `ChatOpenAI` to make calls.
#
# <span style='color: red; font-weight: bold;'>⚠️ 此部分教程当前版本 Langchain 还没有支持，以后再来探索吧 ⚠️</span>
#
# <span style='color: red; font-weight: bold;'>⚠️ This part is not supported by the current version of Langchain, please explore it later ⚠️</span>

# %% [markdown]
# ## 1. Install Langchain
#
# 由于本教程需要使用 Langchain进行调用，因此我们首先需要安装 Langchain 和 对应的依赖包。
#
# Since this tutorial requires Langchain to be called, you first need to install Langchain and the corresponding dependency packages.

# %%
! pip install langchain langchainhub httpx_sse
# Out:
# Collecting langchain
#   Using cached langchain-0.1.12-py3-none-any.whl.metadata (13 kB)
# Collecting langchainhub
#   Downloading langchainhub-0.1.15-py3-none-any.whl.metadata (621 bytes)
# Collecting httpx_sse
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from langchain) (6.0.1)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.28-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.28 (from langchain)
#   Using cached langchain_community-0.0.28-py3-none-any.whl.metadata (8.3 kB)
# Collecting langchain-core<0.2.0,>=0.1.31 (from langchain)
#   Downloading langchain_core-0.1.32-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Using cached langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.26-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from langchain) (2.6.4)
# Requirement already satisfied: requests<3,>=2 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from langchain) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.31.0.20240311-py3-none-any.whl.metadata (1.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading frozenlist-1.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading multidict-6.0.5-cp311-cp311-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Downloading yarl-1.9.4-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: anyio<5,>=3 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from langchain-core<0.2.0,>=0.1.31->langchain) (4.3.0)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.31->langchain)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.9.15-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/50.7 kB ? eta -:--:--
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ----------------------- --------------- 30.7/50.7 kB 32.0 kB/s eta 0:00:01
#      ------------------------------- ------- 41.0/50.7 kB 20.9 kB/s eta 0:00:01
#      ------------------------------- ------- 41.0/50.7 kB 20.9 kB/s eta 0:00:01
#      ------------------------------- ------- 41.0/50.7 kB 20.9 kB/s eta 0:00:01
#      --------------------------------------- 50.7/50.7 kB 25.1 kB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from pydantic<3,>=1->langchain) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: sniffio>=1.1 in d:\sdk\anaconda3\envs\zhipu\lib\site-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain) (1.3.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain-0.1.12-py3-none-any.whl (809 kB)
# Downloading langchainhub-0.1.15-py3-none-any.whl (4.6 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading aiohttp-3.9.3-cp311-cp311-win_amd64.whl (365 kB)
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/365.3 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    --- ------------------------------------ 30.7/365.3 kB 37.4 kB/s eta 0:00:09
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ---- ----------------------------------- 41.0/365.3 kB 17.9 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------ --------------------------------- 61.4/365.3 kB 16.8 kB/s eta 0:00:19
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ------- -------------------------------- 71.7/365.3 kB 12.0 kB/s eta 0:00:25
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- ----------------------------- 92.2/365.3 kB 13.1 kB/s eta 0:00:21
#    ---------- -----------------------------
/s eta 0:00:01
#    ---------------- ----------------------- 30.7/76.7 kB 81.9 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.7 kB 70.1 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.7 kB 70.1 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.7 kB 70.1 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.7 kB 70.1 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.7 kB 70.1 kB/s eta 0:00:01
#    -------------------------------- ------- 61.4/76.7 kB 77.9 kB/s eta 0:00:01
#    -------------------------------- ------- 61.4/76.7 kB 77.9 kB/s eta 0:00:01
#    -------------------------------- ------- 61.4/76.7 kB 77.9 kB/s eta 0:00:01
#    ------------------------------------- -- 71.7/76.7 kB 75.6 kB/s eta 0:00:01
#    ---------------------------------------- 76.7/76.7 kB 81.8 kB/s eta 0:00:00
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: types-requests, tenacity, packaging, orjson, mypy-extensions, multidict, jsonpatch, httpx_sse, greenlet, frozenlist, yarl, typing-inspect, SQLAlchemy, marshmallow, langchainhub, aiosignal, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed SQLAlchemy-2.0.28 aiohttp-3.9.3 aiosignal-1.3.1 dataclasses-json-0.6.4 frozenlist-1.4.1 greenlet-3.0.3 httpx_sse-0.4.0 jsonpatch-1.33 langchain-0.1.12 langchain-community-0.0.28 langchain-core-0.1.32 langchain-text-splitters-0.0.1 langchainhub-0.1.15 langsmith-0.1.26 marshmallow-3.21.1 multidict-6.0.5 mypy-extensions-1.0.0 orjson-3.9.15 packaging-23.2 tenacity-8.2.3 types-requests-2.31.0.20240311 typing-inspect-0.9.0 yarl-1.9.4

# %% [markdown]
# 现在，设置好 ZhipuAI 的 API Key，这样我们就可以使用 ZhipuAI 的 GLM-4 模型了。
# Now, you need to set up ZhipuAI’s API Key so that you can use ZhipuAI’s GLM-4 model.
# > 如果你需要使用本章节的第 4 部分教程，你需要填写 TAVILY_API_KEY，该工具用于执行 Langchain 的 工具调用。
# If you need to use the fourth part of the tutorial in this chapter, you need to fill in TAVILY_API_KEY, which is used to execute Langchain’s tool calls.

# %%
import os

#os.environ["ZHIPUAI_API_KEY"] = "your zhipu api key"
#os.environ["TAVILY_API_KEY"] = "your tavily api key"

# %% [markdown]
# ## 2. Use the method of `ChatZhipuAI` class to call ZhipuAI’s GLM-4 model
#
# 和 `ChatOpenAI` 类一样，`ChatZhipuAI` 类也是一个可以调用 ZhipuAI 的 GLM-4 模型的类，我们可以使用 `ChatZhipuAI`来替换 `ChatOpenAI` 类，直接无缝对接到自己的项目中。这里展现了一个最基本的调用方法。
#
# Like the `ChatOpenAI` class, the `ChatZhipuAI` class is also a class that can call ZhipuAI's GLM-4 model. you can use `ChatZhipuAI` to replace the `ChatOpenAI` class and directly and seamlessly connect it to our own projects. Here is a basic calling method.

# %%
from langchain_community.chat_models.zhipuai import ChatZhipuAI
from langchain.schema import HumanMessage, SystemMessage

messages = [

    SystemMessage(
        content="You are a smart assistant, please reply to me smartly."
    ),
    HumanMessage(
        content="There were 9 birds on the tree. The hunter shot and killed one. How many birds were there?"
    ),
]

llm = ChatZhipuAI(
    temperature=0.95,
    model="glm-4"
)

llm(messages)
# Out:
# d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 19
#       4 messages = [
#       5
#       6     SystemMessage(
#    (...)
#      11     ),
#      12 ]
#      14 llm = ChatZhipuAI(
#      15     temperature=0.95,
#      16     model="glm-4"
#      17 )
# ---> 19 llm(messages)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:711, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     703 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     704 def __call__(
#     705     self,
#    (...)
#     709     **kwargs: Any,
#     710 ) -> BaseMessage:
# --> 711     generation = self.generate(
#     712         [messages], stop=stop, callbacks=callbacks, **kwargs
#     713     ).generations[0][0]
#     714     if isinstance(generation, ChatGeneration):
#     715         return generation.message
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:434, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     432         if run_managers:
#     433             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 434         raise e
#     435 flattened_outputs = [
#     436     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     437     for res in results
#     438 ]
#     439 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:424, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     421 for i, m in enumerate(messages):
#     422     try:
#     423         results.append(
# --> 424             self._generate_with_cache(
#     425                 m,
#     426                 stop=stop,
#     427                 run_manager=run_managers[i] if run_managers else None,
#     428                 **kwargs,
#     429             )
#     430         )
#     431     except BaseException as e:
#     432         if run_managers:
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:608, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     604         raise ValueError(
#     605             "Asked to cache, but no cache found at `langchain.cache`."
#     606         )
#     607 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 608     result = self._generate(
#     609         messages, stop=stop, run_manager=run_manager, **kwargs
#     610     )
#     611 else:
#     612     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_community\chat_models\zhipuai.py:267, in ChatZhipuAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     264 if not should_stream:
#     265     response = self.invoke(prompt)
# --> 267     if response["code"] != 200:
#     268         raise RuntimeError(response)
#     270     content = response["data"]["choices"][0]["content"]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ## 3. Use Langchain to call your own fine-tuned model.
#
# ZhipuAI 已经支持使用 Langchain 调用微调的 ChatGLM 系列模型，如果你想学习如何微调模型，请查看[微调教程](../finetune/glm_lora_finetune_pysdk.ipynb) 来微调自己的模型。
#
# ZhipuAI already supports using Langchain to call the fine-tuned ChatGLM series models. If you want to learn how to fine-tune the model, please view the [Fine-tuning Tutorial](../finetune/glm_lora_finetune_pysdk.ipynb) to fine-tune your own model

# %%
messages = [
    HumanMessage(
        content="类型#裤*风格#英伦*风格#简约"
    ),
]
fine_tuned_model = ChatZhipuAI(
    temperature=0.2, model_name="ft:chatglm3-6b:advertise_gen:sg59pfxk"
)
fine_tuned_model(messages)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       1 messages = [
#       2     HumanMessage(
#       3         content="类型#裤*风格#英伦*风格#简约"
#       4     ),
#       5 ]
#       6 fine_tuned_model = ChatZhipuAI(
#       7     temperature=0.2, model_name="ft:chatglm3-6b:advertise_gen:sg59pfxk"
#       8 )
# ----> 9 fine_tuned_model(messages)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:711, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     703 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     704 def __call__(
#     705     self,
#    (...)
#     709     **kwargs: Any,
#     710 ) -> BaseMessage:
# --> 711     generation = self.generate(
#     712         [messages], stop=stop, callbacks=callbacks, **kwargs
#     713     ).generations[0][0]
#     714     if isinstance(generation, ChatGeneration):
#     715         return generation.message
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:434, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     432         if run_managers:
#     433             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 434         raise e
#     435 flattened_outputs = [
#     436     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     437     for res in results
#     438 ]
#     439 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:424, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     421 for i, m in enumerate(messages):
#     422     try:
#     423         results.append(
# --> 424             self._generate_with_cache(
#     425                 m,
#     426                 stop=stop,
#     427                 run_manager=run_managers[i] if run_managers else None,
#     428                 **kwargs,
#     429             )
#     430         )
#     431     except BaseException as e:
#     432         if run_managers:
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\language_models\chat_models.py:608, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     604         raise ValueError(
#     605             "Asked to cache, but no cache found at `langchain.cache`."
#     606         )
#     607 if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 608     result = self._generate(
#     609         messages, stop=stop, run_manager=run_manager, **kwargs
#     610     )
#     611 else:
#     612     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_community\chat_models\zhipuai.py:265, in ChatZhipuAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     263 should_stream = stream if stream is not None else self.streaming
#     264 if not should_stream:
# --> 265     response = self.invoke(prompt)
#     267     if response["code"] != 200:
#     268         raise RuntimeError(response)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_community\chat_models\zhipuai.py:183, in ChatZhipuAI.invoke(self, prompt)
#     181 def invoke(self, prompt: Any) -> Any:  # type: ignore[override]
#     182     if self.model == "chatglm_turbo":
# --> 183         return self.zhipuai.model_api.invoke(
#     184             model=self.model,
#     185             prompt=prompt,
#     186             top_p=self.top_p,
#     187             temperature=self.temperature,
#     188             request_id=self.request_id,
#     189             return_type=self.return_type,
#     190         )
#     191     elif self.model == "characterglm":
#     192         _meta = cast(meta, self.meta).dict()
#
# AttributeError: module 'zhipuai' has no attribute 'model_api'

# %% [markdown]
# ## 4. 使用 Langchain 来完成一个简单的 Function Call 调用
#
# 得益于 ZhipuAI 也具有极强的 工具调用能力，你可以使用它来完成 Langchain中的 `Agent` 类的功能，这里我们展示了一个简单的调用方法。
#
# 我参考 [Langchain 官方教程](https://python.langchain.com/docs/modules/agents/agent_types/openai_functions_agent) 的方案，并仅仅将 `ChatOpenAI`替换为`ChatZhipuAI`，除了模型加载方式，在 Agent 代码中完全不用进行任何代码修改。
#
# Thanks to ZhipuAI's strong tool calling capabilities, you can use it to complete the functions of the `Agent` class in Langchain. Here we show a simple calling method.
#
# I refer to the solution of [Langchain official tutorial](https://python.langchain.com/docs/modules/agents/agent_types/openai_functions_agent) and just replace `ChatOpenAI` with `ChatZhipuAI`. Except for the model loading method, in Agent There is absolutely no need to make any code modifications in the code.

# %%
from langchain import hub
from langchain.agents import AgentExecutor, create_json_chat_agent
from langchain_community.tools.tavily_search import TavilySearchResults
tools = [TavilySearchResults(max_results=1)]
prompt = hub.pull("hwchase17/react-chat-json")
agent = create_json_chat_agent(llm, tools, prompt)
agent_executor = AgentExecutor(
    agent=agent, tools=tools, verbose=True, handle_parsing_errors=True
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 4
#       2 from langchain.agents import AgentExecutor, create_json_chat_agent
#       3 from langchain_community.tools.tavily_search import TavilySearchResults
# ----> 4 tools = [TavilySearchResults(max_results=1)]
#       5 prompt = hub.pull("hwchase17/react-chat-json")
#       6 agent = create_json_chat_agent(llm, tools, prompt)
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\langchain_core\load\serializable.py:120, in Serializable.__init__(self, **kwargs)
#     119 def __init__(self, **kwargs: Any) -> None:
# --> 120     super().__init__(**kwargs)
#     121     self._lc_kwargs = kwargs
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\pydantic\v1\main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\pydantic\v1\main.py:1064, in validate_model(model, input_data, cls)
#    1061     errors.append(ErrorWrapper(MissingError(), loc=field.alias))
#    1062     continue
# -> 1064 value = field.get_default()
#    1066 if not config.validate_all and not field.validate_always:
#    1067     values[name] = value
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\pydantic\v1\fields.py:437, in ModelField.get_default(self)
#     436 def get_default(self) -> Any:
# --> 437     return smart_deepcopy(self.default) if self.default_factory is None else self.default_factory()
#
# File d:\sdk\Anaconda3\envs\zhipu\Lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for TavilySearchAPIWrapper
# __root__
#   Did not find tavily_api_key, please add an environment variable `TAVILY_API_KEY` which contains it, or pass `tavily_api_key` as a named parameter. (type=value_error)

# %% [markdown]
# 接着，我们执行这个代码，就可以获得正确的答案。观察到智谱AI 能直接无缝的使用 Langchain 的 `Agent` 类的功能。
# Then, we execute this code and get the correct answer. It is observed that Zhipu AI can directly and seamlessly use the functions of Langchain's `Agent` class.

# %%
agent_executor.invoke({"input": "what is LangChain?"})
# Out:
# > Entering new AgentExecutor chain...
# ```json
# {
#     "action": "tavily_search_results_json",
#     "action_input": "LangChain"
# }
# ```[{'url': 'https://blog.stackademic.com/langchain-in-chains-1-a-closer-look-a6bbaa246ccb', 'content': 'Langchain  LangChain is an open-source framework designed to simplify the creation of applications using large language models  Langchain provides various components that make it easier to integrate and manage models in different application  LangChain is a framework for developing applications powered by language models. It enables applications that:The LLMs and Chat Models component of Langchain provides a framework for integrating and managing various large language models (LLMs), including specialized chat models, within applications. Prompts and Parsers streamline the model inputs and outputs. In the subsequent sections of this series, we will closely examine each concept. Next:'}]```json
# {
#     "action": "Final Answer",
#     "action_input": "LangChain is an open-source framework designed to simplify the creation of applications using large language models. It provides various components that make it easier to integrate and manage models in different applications, enabling the development of applications powered by language models. This includes integrating and managing large language models and chat models, as well as streamlining model inputs and outputs with prompts and parsers."
# }
# ```
#
# > Finished chain.
# {'input': 'what is LangChain?',
#  'output': 'LangChain is an open-source framework designed to simplify the creation of applications using large language models. It provides various components that make it easier to integrate and manage models in different applications, enabling the development of applications powered by language models. This includes integrating and managing large language models and chat models, as well as streamlining model inputs and outputs with prompts and parsers.'}

# %% [markdown]
# ## Conclusion
#
# 通过本教程，您将能快速的切换 `Langchain` 的模型读入，将模型切换为 ZhipuAI 的 GLM-4 系列模型。本代码只是基础教程，我将于之后推出更多进阶的使用 GLM-4 系列模型和 Langchain 的配合作品。
#
# Through this tutorial, you will be able to quickly switch to `Langchain` model reading and switch the model to ZhipuAI's GLM-4 series model. This code is just a basic tutorial. I will launch more advanced works using GLM-4 series models and Langchain in the future.
